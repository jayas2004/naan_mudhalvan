# %%
# !pip install pandas numpy matplotlib seaborn nltk scikit-learn transformers wordcloud streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 71.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv("/content/chatgpt_reviews.csv")
df.head()
# Out:
#          date                 title  \
# 0   2/15/2025            Impressive
# 1  10/16/2024         Waste of Time
# 2  10/16/2024         Waste of Time
# 3  12/21/2024          Not Accurate
# 4   3/23/2025  Fantastic Experience
#
#                                               review  rating       username  \
# 0  Mother former community upon vote fact. Sure s...     2.0          ybass
# 1  General paper understand main. Or age half won...     5.0        glenn33
# 2  Here situation his high stage. Agree certainly...     4.0       debbie27
# 3  Rule court behind growth reality. Tonight whos...     1.0  hannahrussell
# 4  Case opportunity season road write. Effort gre...     3.0        cnorton
#
#    helpful_votes  review_length platform language   location  version  \
# 0           68.0           78.0   Mobile       es     Canada      3.0
# 1           71.0          193.0      Web       de      India      4.1
# 2           66.0          184.0      Web       hi      India      4.1
# ...

# %%
# Required imports
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Re-download NLTK resources after runtime restart
nltk.download('punkt', force=True)
nltk.download('stopwords', force=True)
nltk.download('wordnet', force=True)

# Set up stopwords and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Text cleaning function
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)
    text = re.sub(r'\@w+|\#','', text)
    text = re.sub(r'[^\w\s]', '', text)
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return " ".join(filtered_tokens)

# Apply cleaning to the correct column ('content')
df['cleaned_review'] = df['content'].apply(clean_text)

# Show a sample
df[['content', 'cleaned_review']].head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
print(df.columns)
# Out:
# Index(['date', 'title', 'review', 'rating', 'username', 'helpful_votes',
#        'review_length', 'platform', 'language', 'location', 'version',
#        'verified_purchase', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Setup
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Define cleaning function
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)     # Remove links
    text = re.sub(r'\@\w+|\#', '', text)                    # Remove @mentions and hashtags
    text = re.sub(r'[^\w\s]', '', text)                     # Remove punctuation
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return " ".join(filtered_tokens)

# Apply cleaning to the correct column
df['cleaned_review'] = df['review'].apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-11-e041d7b12cd5> in <cell line: 0>()
#      28
#      29 # Apply cleaning to the correct column
# ---> 30 df['cleaned_review'] = df['review'].apply(clean_text)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# ...

# %%
import nltk
import shutil
import os

# Delete the 'punkt' tokenizer folder manually if it exists
punkt_path = os.path.join(nltk.data.find('tokenizers/punkt').path) if 'punkt' in nltk.data.path[0] else None
if punkt_path and os.path.exists(punkt_path):
    shutil.rmtree(punkt_path)

# Redownload punkt
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)
    text = re.sub(r'\@\w+|\#', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    tokens = text.split()  # fallback instead of nltk.word_tokenize
    filtered_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return " ".join(filtered_tokens)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Download required NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Initialize stopwords and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Load your DataFrame
df = pd.read_csv('/content/chatgpt_reviews.csv')  # Adjust path if needed

# Check column names
print(df.columns)

# Drop missing reviews
df.dropna(subset=['review'], inplace=True)

# Text cleaning function (uses simple split to avoid punkt issues)
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)
    text = re.sub(r'\@\w+|\#', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    tokens = text.split()  # safer alternative to nltk.word_tokenize
    filtered_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return " ".join(filtered_tokens)

# Apply cleaning
df['cleaned_review'] = df['review'].apply(clean_text)

# TF-IDF vectorization
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['cleaned_review'])

# Compute pairwise cosine similarity (optional)
cosine_sim = cosine_similarity(tfidf_matrix)

# Example: most similar reviews to the first review
similar_indices = cosine_sim[0].argsort()[-6:][::-1]  # top 5 similar (excluding itself)
print("Most similar reviews to the first one:")
print(df.iloc[similar_indices][['review']])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Index(['date', 'title', 'review', 'rating', 'username', 'helpful_votes',
#        'review_length', 'platform', 'language', 'location', 'version',
#        'verified_purchase', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')
# Most similar reviews to the first one:
#                                                  review
# 0     Mother former community upon vote fact. Sure s...
# 1566  About should their soldier. Character stage wi...
# 2838  Agency for newspaper might hold these. Back th...
# 256   No whose marriage close.\nAccept accept say. S...
# 6884  Community man sure cost worker. From baby bar ...
# ...
